# %% [markdown]
# <a href="https://colab.research.google.com/github/BandaAkshitha/Natural-Language-Processing/blob/main/NLP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy

# %%
import nltk
import spacy

# %%
text = """Natural Language Processing is a branch of Artificial Intelligence
that helps computers understand, interpret, and generate human language."""

# %%
words = text.split()
word_count = len(words)
print("Number of words:", word_count)
# Out:
# Number of words: 18

# %%
lower_text = text.lower()
print("Text in lowercase:")
print(lower_text)
# Out:
# Text in lowercase:
# natural language processing is a branch of artificial intelligence
# that helps computers understand, interpret, and generate human language.
